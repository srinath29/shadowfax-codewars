# %%
# %matplotlib inline
import sys
import pandas
import json
import matplotlib.pyplot as plot
import numpy as np
import os

# %%
cwd = os.getcwd()
dataDir = os.path.join(os.path.abspath(os.path.join(cwd,os.pardir)),"Data")
sys.path.append(os.path.join(os.path.abspath(os.path.join(cwd,os.pardir)),"utils"))
import utils

# %%
import googlemaps
import datetime
import json
import pandas as pd



class Helper :

    def getDistanceMatrix(self, origins, destinations):
        gmaps = googlemaps.Client(key="AIzaSyCTVcmF2m7PGO1UgEEv9Mfn-Vo0XbA5XYY")
        return gmaps.distance_matrix(origins, destinations,
                                     mode="driving",
                                     departure_time=datetime.datetime.now())

    def distance_dataFrame(self, json_obj):
        all_distance = []
        for elements_list in json_obj['rows']:
            distance_list = []
            for element in elements_list['elements']:
                distance_list.append(element['distance']['value'])
            all_distance.append(distance_list)

        return pd.DataFrame(all_distance)
    
    def getDistanceDataFrame(self, origins, destinations):
        k = self.getDistanceMatrix(origins, destinations)
        return self.distance_dataFrame(k)

# %%
orderDf = pandas.read_csv(os.path.join(dataDir, "order_data.csv"))
riderDf = pandas.read_csv(os.path.join(dataDir,"rider_location.csv"))

# %%
#converting to datetime format
orderDf["scheduled_time"] = pandas.to_datetime(orderDf["scheduled_time"], errors='coerce')
orderDf["delivered_time"] = pandas.to_datetime(orderDf["delivered_time"], errors='coerce')

# %% [raw]
# orderDf.dtypes

# %%
dataDir
# Out:
# '/home/cmehta/Documents/hackathon/shadowfax-codewars/Data'

# %%
orderDf
# Out:
#       order_id  seller_id  rider_id  cluster_id      scheduled_time  \
# 0      1865297       2213      2765          56 2016-04-03 05:01:45
# 1      1866145       2287      3368          91 2016-04-03 05:50:44
# 2      1866147        343       973          41 2016-04-03 05:50:56
# 3      1866159       2287      3316          91 2016-04-03 05:50:36
# 4      1866218       2313      3424          56 2016-04-03 05:51:55
# 5      1866341        310      1385          39 2016-04-03 06:02:11
# 6      1866406       2357      2158          52 2016-04-03 06:03:30
# 7      1866466       2287      3316          91 2016-04-03 06:08:38
# 8      1866472       2287      3502          91 2016-04-03 06:09:09
# 9      1866501       2243      3052          96 2016-04-03 06:07:59
# 10     1866532       2357      2373          52 2016-04-03 06:11:29
# 11     1866553        655      1281         100 2016-04-03 06:12:29
# 12     1866630        655      1303         100 2016-04-03 06:18:38
# ...

# %%
orderDf.dtypes
# Out:
# order_id                        int64
# seller_id                       int64
# rider_id                        int64
# cluster_id                      int64
# scheduled_time         datetime64[ns]
# delivered_time         datetime64[ns]
# pickup_latitude               float64
# pickup_longitude              float64
# delivered_latitude            float64
# delivered_longitude           float64
# dtype: object

# %%
#Nats in the dataframe
sum(orderDf["delivered_time"].isnull())/orderDf.shape[0]
# Out:
# 0.29819524200164071

# %%
orderDfRemovedNat = orderDf[orderDf["delivered_time"].notnull()]

# %%
orderDfRemovedNat["TimeTakenForDelivery"] = (orderDfRemovedNat["delivered_time"] - orderDfRemovedNat["scheduled_time"]).map(lambda x: x.total_seconds()/60)
# Out:
# /home/cmehta/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
#checking delivery time
mean = orderDfRemovedNat["TimeTakenForDelivery"].mean()
percentPeopleBelowMean = sum(orderDfRemovedNat["TimeTakenForDelivery"]<= mean)/orderDfRemovedNat.shape[0]

# %%
meanOfBoysDeliveringAboveTotalMean = orderDfRemovedNat["TimeTakenForDelivery"][orderDfRemovedNat["TimeTakenForDelivery"]> mean].mean()
numSuchAbovePeople = orderDfRemovedNat["TimeTakenForDelivery"][orderDfRemovedNat["TimeTakenForDelivery"]> mean].count()
maxOfSuchAbove = orderDfRemovedNat["TimeTakenForDelivery"][orderDfRemovedNat["TimeTakenForDelivery"]> mean].max()
minSuchAbove = orderDfRemovedNat["TimeTakenForDelivery"][orderDfRemovedNat["TimeTakenForDelivery"]> mean].min()

# %%
orderDfRemovedNat
# Out:
#       order_id  seller_id  rider_id  cluster_id      scheduled_time  \
# 0      1865297       2213      2765          56 2016-04-03 05:01:45
# 2      1866147        343       973          41 2016-04-03 05:50:56
# 3      1866159       2287      3316          91 2016-04-03 05:50:36
# 5      1866341        310      1385          39 2016-04-03 06:02:11
# 6      1866406       2357      2158          52 2016-04-03 06:03:30
# 7      1866466       2287      3316          91 2016-04-03 06:08:38
# 10     1866532       2357      2373          52 2016-04-03 06:11:29
# 11     1866553        655      1281         100 2016-04-03 06:12:29
# 13     1866633       2357      2373          52 2016-04-03 06:19:15
# 14     1866636        343       972          41 2016-04-03 06:17:11
# 15     1866642       1991      1267          52 2016-04-03 06:18:35
# 16     1866778       1972      3105          41 2016-04-03 06:24:28
# 18     1866785       1972      3105          41 2016-04-03 06:27:51
# ...

# %%
originAddresses = list(zip(orderDfRemovedNat["pickup_latitude"], orderDfRemovedNat["pickup_longitude"]))

# %%
deliveredAddresses = list(zip(orderDfRemovedNat["delivered_latitude"], orderDfRemovedNat["delivered_longitude"]))

# %%
h1 = Helper()

# %%
"""
def getSpeed(pLan, pLon, dLan, dLon, timeTaken):
    li = []
    for plan, plon, dlan, dlon, ti in list(zip(pLan, pLon, dLan, dLon, timeTaken)):
        k=h1.getDistanceDataFrame((plan, plon), (dlan, dlon))
        #print(k)
        li.append(k[0][0]/ti*60)
    #ind = x.index
    #origin = (orderDfRemovedNat.ix[ind,"pickup_latitude"],orderDfRemovedNat.ix[ind,"pickup_longitude"])
    #destination = (orderDfRemovedNat.ix[ind,"delivered_latitude"],orderDfRemovedNat.ix[ind,"delivered_longitude"])
    #return h1.getDistanceMatrix(origin, destination)[0][0]/(orderDfRemovedNat.ix[ind,"TimeTakenForDelivery"]*60)
    return pandas.Series(li)

orderDfRemovedNat["Speed"] = getSpeed(orderDfRemovedNat["pickup_latitude"], orderDfRemovedNat["pickup_longitude"], orderDfRemovedNat["delivered_latitude"], orderDfRemovedNat["delivered_longitude"], orderDfRemovedNat["TimeTakenForDelivery"])
"""
# Out:
# '\ndef getSpeed(pLan, pLon, dLan, dLon, timeTaken):\n    li = []\n    for plan, plon, dlan, dlon, ti in list(zip(pLan, pLon, dLan, dLon, timeTaken)):\n        k=h1.getDistanceDataFrame((plan, plon), (dlan, dlon))\n        #print(k)\n        li.append(k[0][0]/ti*60)\n    #ind = x.index\n    #origin = (orderDfRemovedNat.ix[ind,"pickup_latitude"],orderDfRemovedNat.ix[ind,"pickup_longitude"])\n    #destination = (orderDfRemovedNat.ix[ind,"delivered_latitude"],orderDfRemovedNat.ix[ind,"delivered_longitude"])\n    #return h1.getDistanceMatrix(origin, destination)[0][0]/(orderDfRemovedNat.ix[ind,"TimeTakenForDelivery"]*60)\n    return pandas.Series(li)\n\norderDfRemovedNat["Speed"] = getSpeed(orderDfRemovedNat["pickup_latitude"], orderDfRemovedNat["pickup_longitude"], orderDfRemovedNat["delivered_latitude"], orderDfRemovedNat["delivered_longitude"], orderDfRemovedNat["TimeTakenForDelivery"])\n'

# %%
groupedCluster = orderDf.groupby(["cluster_id"])

# %%
df = pandas.DataFrame()

# %%
df["hello"] = pandas.Series([1,2,3])

# %%
di = {"a":1, "b":2, "c":3}

# %%
list(di.keys())
# Out:
# ['b', 'a', 'c']

# %%
df
# Out:
#    hello
# b      1
# a      2
# c      3
